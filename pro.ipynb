# %%
import pandas as pd
from sklearn.metrics import r2_score, accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
df=pd.read_csv('music1.csv',encoding='ISO-8859-1')
df
# Out:
#                        song_name  \
# 0             Pehle Lalkare Naal
# 1    Sharbat Wangu Ghut Bhar Lan
# 2          Das Meriya Dilwara ve
# 3           Dhokha Nahin Kamaida
# 4     Sikhar Dupehre Nahaundi Si
# ..                           ...
# 411                    mad world
# 412                         hurt
# 413       tears dry on their own
# 414            since u been gone
# 415                   hallelujah
#
#                                                 poster duration  popularity  \
# 0    ......    03:31          96
# 1    ......    04:24          44
# 2    ......    06:18          33
# 3    ......    04:28          47
# 4    ......    04:18          76
# ..                                                 ...      ...         ...
# 411  ......    03:05          79
# 412  ......    03:38          85
# 413  ......    03:08          36
# 414  ......    03:08          81
# 415  ......    04:39          94
#
#                           singer Genre language
# ...

# %%
df.drop('duration',axis=1,inplace=True)
df.drop('popularity',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   song_name  416 non-null    object
#  1   poster     416 non-null    object
#  2   singer     416 non-null    object
#  3   Genre      416 non-null    object
#  4   language   416 non-null    object
# dtypes: object(5)
# memory usage: 16.4+ KB

# %%
#x=df.iloc[:,1:]# independent variables
#y=df.loc[:,'song_name']# dependent variables
#x

# %%
x.shape
# Out:
# (416, 3)

# %%
df.shape
# Out:
# (416, 5)

# %%
y
# Out:
# 0               Pehle Lalkare Naal
# 1      Sharbat Wangu Ghut Bhar Lan
# 2            Das Meriya Dilwara ve
# 3             Dhokha Nahin Kamaida
# 4       Sikhar Dupehre Nahaundi Si
#                   ...
# 411                      mad world
# 412                           hurt
# 413         tears dry on their own
# 414              since u been gone
# 415                     hallelujah
# Name: song_name, Length: 416, dtype: object

# %%
y.shape
# Out:
# (416,)

# %%
encoder=LabelEncoder()
df['gen']=encoder.fit_transform(df[['Genre']])
df['sin']=encoder.fit_transform(df[['singer']])
df['lan']=encoder.fit_transform(df[['language']])
df['song_name']=encoder.fit_transform(df['song_name'])
df
# Out:
# C:\Users\Yashika Kapoor\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Yashika Kapoor\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Yashika Kapoor\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
x=df[['sin','gen','lan']]#independent
y=df['song_name']# dependent
x
# Out:
#      sin  gen  lan
# 0     16    1    2
# 1     16    0    2
# 2     42   14    2
# 3     16   14    2
# 4     16   14    2
# ..   ...  ...  ...
# 411  198   23    0
# 412  213   23    0
# 413  161   23    0
# 414  225   23    0
# 415  233   23    0
#
# [416 rows x 3 columns]

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
model=KNeighborsClassifier(n_neighbors=7,p=2)
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array(['Bade Achhe Lagte Hain', 'Aaja Sonie', 'Pehle Lalkare Naal',
#        '8 parche', '8 asle', 'Sada Dil Mod De',
#        'Charkha Mera Rangla - Live', 'Dhokha Nahin Kamaida',
#        'Gun Gobind Gayo Nahin', 'Kala Doria', 'Main Yamla Jatt',
#        'Lara Lappa Lai Rakhdi', 'Aaja Sonie', 'dance meri rani',
#        'Aa Mundiya Ve Tu', 'I am in love', 'Aaj Phir Tumpe',
#        'Janu Meri Jaan', 'channa mereya', 'I am in love',
#        'Main Yamla Jatt', 'Ek Gal Puchhan', 'anti hero', '09:45',
#        'Dum Maro Dum', 'beedi', '09:45', 'Koi Dardi Disda Na',
#        'Ik Kurhi Pataka', 'I am in love', 'Barin Barsin Khattan Gaya',
#        'Abhi Na Jao Chhod Kar', 'Gun Gobind Gayo Nahin',
#        'Sas Gode Thale Lai Layi', 'Sada Dil Mod De', 'Aaja Sonie',
#        '09:45', 'Ae Mere Zohra Jabeen', 'Jis Dil Wich Sajnan Was Jayie',
#        'Sikhar Dupehre Nahaundi Si', 'Ik Kudi Jehda Naa Mohabbat',
#        'Abhi Na Jao Chhod Kar', 'celebration', 'I am in love',
# ...

# %%
r2_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 r2_score(y_test,y_pred)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
# ...
